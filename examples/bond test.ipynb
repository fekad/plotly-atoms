# %%
from plotly_atoms import Figure
from plotly_atoms import shapes

# %%
fig = Figure()

fig.add_trace(shapes.get_sphere(point=[0,0,0], radius=.5, color='green'))
fig.add_trace(shapes.get_sphere(point=[0,0,1], radius=.5, color='green'))
fig.add_trace(shapes.get_cylinder([0,0,1], [0,0,0], radius=.45, color='grey'))
fig.show()
# Out:
# [-0.  0.  0.]

# %%
from pymatgen.core import Lattice, Structure, Molecule
from pymatgen.analysis import local_env

coords = [[0, 0, 0], [0.75,0.5,0.75]]
lattice = Lattice.from_parameters(a=3.84, b=3.84, c=3.84, alpha=120,
                                  beta=90, gamma=60)
struct = Structure(lattice, ["Si", "Si"], coords)

coords = [[0.000000, 0.000000, 0.000000],
          [0.000000, 0.000000, 1.089000],
          [1.026719, 0.000000, -0.363000],
          [-0.513360, -0.889165, -0.363000],
          [-0.513360, 0.889165, -0.363000]]
methane = Molecule(["C", "H", "H", "H", "H"], coords)

# %%
a = local_env.CrystalNN().get_bonded_structure(struct)
# Out:
# /Users/fekad/.conda/envs/abinit-panel/lib/python3.8/site-packages/pymatgen/analysis/local_env.py:4142: UserWarning:
#
# No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#
# /Users/fekad/.conda/envs/abinit-panel/lib/python3.8/site-packages/pymatgen/analysis/local_env.py:3945: UserWarning:
#
# CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.

# %%
b = local_env.CovalentBondNN().get_bonded_structure(methane)
b
# Out:
# Molecule Graph
# Molecule:
# Molecule Summary
# Site: C (0.0000, 0.0000, 0.0000)
# Site: H (0.0000, 0.0000, 1.0890)
# Site: H (1.0267, 0.0000, -0.3630)
# Site: H (-0.5134, -0.8892, -0.3630)
# Site: H (-0.5134, 0.8892, -0.3630)
# Graph: bonds
# from    to  to_image      weight
# ----  ----  ------------  ------------------
#    0     1  (0, 0, 0)     9.583e-01
#    0     2  (0, 0, 0)     9.583e-01
#    0     3  (0, 0, 0)     9.583e-01
#    0     4  (0, 0, 0)     9.583e-01

# %%
b
# Out:
# Molecule Graph
# Molecule:
# Molecule Summary
# Site: C (0.0000, 0.0000, 0.0000)
# Site: H (0.0000, 0.0000, 1.0890)
# Site: H (1.0267, 0.0000, -0.3630)
# Site: H (-0.5134, -0.8892, -0.3630)
# Site: H (-0.5134, 0.8892, -0.3630)
# Graph: bonds
# from    to  to_image      weight
# ----  ----  ------------  ------------------
#    0     1  (0, 0, 0)     9.583e-01
#    0     2  (0, 0, 0)     9.583e-01
#    0     3  (0, 0, 0)     9.583e-01
#    0     4  (0, 0, 0)     9.583e-01

# %%
b.bonds
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/r0/h6qcb1qs2zv9drfhsjnkxr340000gn/T/ipykernel_25148/919957626.py in <module>
# ----> 1 b.bonds
#
# AttributeError: 'MoleculeGraph' object has no attribute 'bonds'
